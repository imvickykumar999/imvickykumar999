# %%
import pandas as pd

df = pd.read_csv ('Event Registration (Responses) - Form Responses 1.csv') 
df = df.drop(df.index[7])
df
# Out:
#              Timestamp              FULL NAME ( Team Leader )  \
# 0   6/11/2021 13:54:02                            Omjee yadav
# 1   6/11/2021 13:54:49                           Ashish Kumar
# 2   6/11/2021 16:28:27                          Rajdeep Singh
# 3   6/11/2021 17:52:09                          Sanju Sharma
# 4   6/11/2021 20:24:43                           Ashish Kumar
# 5   6/11/2021 21:53:14                            Vicky Kumar
# 6   6/12/2021 10:22:09                            Vicky Kumar
# 8   6/15/2021 13:32:16                        D.v.n.kameswari
# 9   6/15/2021 14:21:22                       SUBHANKAR HALDER
# 10  6/15/2021 14:29:26                            SUDHARSAN S
# 11  6/15/2021 15:06:40                      VIRAJ KUMAR SINGH
# 12  6/15/2021 22:00:38  SHRIKARUNMATHESH.EE19@BITSATHY.AC.IN
# 13  6/15/2021 22:04:26                   Aleena Sara Varghese
# 14   6/16/2021 8:31:08                       amirthalakshmi k
# 15  6/16/2021 11:50:51                         HARIPRAKAASH N
#
#                EMAIL ID ( Team Leader )  Contact Number ( Team Leader )  \
# 0               omjeeyadav563@gmail.com                    9.694904e+09
# 1           Ashish99anonymous@gmail.com                    7.568441e+09
# 2   19ERECS055.rajdeep@rietjaipur.ac.in                    8.090645e+09
# 3         Sanjusharma14021999@gmail.com                    7.221086e+09
# 4           ashish99anonymous@gmail.com                    7.568441e+09
# 5             imvickykumar999@gmail.com                    8.239958e+09
# 6             imvickykumar999@gmail.com                    8.239958e+09
# 8               kameswari2558@gmail.com                    8.639803e+09
# 9               Subhankar.ee@vitj.ac.in                    9.182097e+11
# 10              sudharsan0693@gmail.com                    7.550264e+09
# 11               viraj.ks2001@gmail.com                    9.939890e+09
# 12                   SHRIKARUNMATHESH S                    9.677205e+09
# 13                aleenasarav@gmail.com                    9.072097e+09
# 14            amirthaammu2002@gmail.com                    6.380516e+09
# 15     hariprakaash.cb20@bitsathy.ac.in                    9.600899e+09
#
#    What is your skill level ?  \
# 0                Intermediate
# 1                Intermediate
# 2                Intermediate
# 3                    Beginner
# 4                Intermediate
# 5                Intermediate
# 6                Intermediate
# 8                Intermediate
# 9                    Beginner
# 10                   Beginner
# 11               Intermediate
# 12                   Beginner
# 13               Intermediate
# 14                   Beginner
# 15               Intermediate
#
#    College Name ( All team members must belong from same College )  \
# 0   Rajasthan institute of engineering and technology
# 1   Rajasthan Institute of engineering and technology
# 2                                                RIET
# 3   Rajasthan institute of engineering and technol...
# 4   Rajasthan Institute of Engineering and Technology
# 5   Rajasthan Institution of Engineering and Techn...
# 6   Rajasthan Institution of Engineering and Techn...
# 8                Vidya Jyothi institute of technology
# 9   Vivekananada institute of technology jagatpura...
# 10                         SSN College Of Engineering
# 11  G.V. Acharya Institute of Engineering and Tech...
# 12             BANNARI AMMAN INSTITUTE OF TECHNOLOGY
# 13        Muthoot Institute of Technology and Science
# 14                  saranathan college of engineering
# 15              Bannari Amman Institute of Technology
#
#     Team Size ( In between 2 members to 4 members ) Full Name ( Member 1 )  \
# 0                                               2.0            omjee yadav
# 1                                               4.0         Himanshu singh
# 2                                               4.0        Badal Chaudhary
# 3                                               2.0           Sanju sharma
# 4                                               4.0         Sagar Jahangid
# 5                                               2.0          Ankit Malpani
# 6                                               3.0          Ankit Malpani
# 8                                               3.0        D.v.n.kameswari
# 9                                               3.0       SUBHANKAR HALDER
# 10                                              3.0            SUDHARSAN S
# 11                                              2.0      VIRAJ KUMAR SINGH
# 12                                              4.0               SURIYA A
# 13                                              4.0   Aleena Sara Varghese
# 14                                              2.0         siva sooriya m
# 15                                              4.0         PAUL DANIEL J
#
#    Contact Number ( Member 1 ) Full Name ( Member 2 )  \
# 0                   9694903744        Devendra suthar
# 1                   7017327841          Tushar kottak
# 2                  99874 88458        Vidhikar Vishal
# 3                   7221085880           Saransh soni
# 4                   8058771157         mahipal pareek
# 5                   7727874136                    NaN
# 6                   7727874136      Anil puri Goswami
# 8                   8639802518                M.divya
# 9                   8209713297               Tejeswar
# 10                  7550264424          Manoj Kumar S
# 11                  9939890224           ANKUSH VARMA
# 12                  6374286944               SURESH K
# 13                  9072096822              Sreeram M
# 14                  8681081973                    NaN
# 15                  7010935411          MAHESHWAR S K
#
#     Contact Number ( Member 2 ) Full Name ( Member 3 )  \
# 0                  7.297075e+09                    NaN
# 1                           NaN         Mahipal pareek
# 2                  9.354057e+09           Udit Narayan
# 3                           NaN                    NaN
# 4                           NaN            Ayush saini
# 5                           NaN                    NaN
# 6                  9.462308e+09                    NaN
# 8                           NaN              K.vasanth
# 9                  8.290127e+09          Mohit kumawat
# 10                 7.589464e+08                  Divya
# 11                 9.769289e+09                    NaN
# 12                 8.072429e+09                SURYA R
# 13                 6.238043e+09              Sindhoora
# 14                          NaN                    NaN
# 15                 8.667421e+09        GOKULA PRSATH M
#
#     Contact Number ( Member 3 )  \
# 0                           NaN
# 1                           NaN
# 2                  6.396835e+09
# 3                           NaN
# 4                  8.109005e+09
# 5                           NaN
# 6                           NaN
# 8                           NaN
# 9                  9.198874e+11
# 10                 9.491790e+09
# 11                          NaN
# 12                 8.056680e+09
# 13                 8.089397e+09
# 14                          NaN
# 15                 6.374510e+09
#
#                  Any Question ? ( Feel free to Ask )           Team Name  \
# 0                                                  No                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                  No              Donjo
# 4                                                 NaN          cyberpunk
# 5                                                 NaN  Boolean Freebirds
# 6                     How many rounds will be there ?  Boolean Freebirds
# 8                                                 NaN         Cocokasaya
# 9   Is there any certification, And when and how w...           Pshypher
# 10                                             Thanks      Innovative AI
# 11                                                NaN             Torque
# 12                                                 No          SMASHERS
# 13                                                NaN               Aura
# 14                                                NaN            thundra
# 15                                                NaN           Gagnants
#
#                         Address of College with State  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                      Jaipur 302021
# 4   Rajasthan Institute of Engineering and Technol...
# 5                        Bhankrota, Jaipur, Rajasthan
# 6                 Bhankrota, Jaipur, Rajasthan, India
# 8   Aziznagar Gate, Chilkur Balaji Road, Himayat S...
# 9               Sysyawas jagatpura Jaipur, Rajasthan.
# 10                  Kelambakkam, Chennai , Tamil Nadu
# 11              Shelu/Damat, Tal- Karjat, Maharashtra
# 12                           SATHYAMANGALAM TAMILNADU
# 13  Muthoot Institute of Technology and Science\nV...
# 14                           trichirapalli, tamilnadu
# 15  Sathy - Bhavani State Highway Alathukombai, Po...
#
#                        Email Address  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 8            kameswari2558@gmail.com
# 9           Subhankar.ee@vitj.ac.in2
# 10           sudharsan0693@gmail.com
# 11            viraj.ks2001@gmail.com
# 12         Surya.ee19@bitsathy.ac.in
# 13             aleenasarav@gmail.com
# 14         amirthaammu2002@gmail.com
# 15  hariprakaash.cb20@bitsathy.ac.in
#
#                Upload Your Idea ( PPT or PDF Format )
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 8   https://drive.google.com/open?id=1VHmnLpd1uETW...
# 9   https://drive.google.com/open?id=1NPmQu7sLvTYG...
# 10  https://drive.google.com/open?id=1Rm3WTn5gcp7i...
# 11  https://drive.google.com/open?id=17t0ZDcAdukir...
# 12  https://drive.google.com/open?id=1fC7Svyj81PLw...
# 13  https://drive.google.com/open?id=1m5dUNm9U0tHo...
# 14  https://drive.google.com/open?id=100HXa18_QsVB...
# 15  https://drive.google.com/open?id=1ZPJJDqMEzsWF...

# %%
mailto = list(set(df['EMAIL ID ( Team Leader )']))
mailto
# Out:
# ['omjeeyadav563@gmail.com',
#  'SHRIKARUNMATHESH S',
#  'ashish99anonymous@gmail.com',
#  'viraj.ks2001@gmail.com',
#  'kameswari2558@gmail.com',
#  'Sanjusharma14021999@gmail.com',
#  'Subhankar.ee@vitj.ac.in',
#  'imvickykumar999@gmail.com',
#  'Ashish99anonymous@gmail.com',
#  'aleenasarav@gmail.com',
#  '19ERECS055.rajdeep@rietjaipur.ac.in',
#  'amirthaammu2002@gmail.com',
#  'sudharsan0693@gmail.com',
#  'hariprakaash.cb20@bitsathy.ac.in']

# %%
', '.join(mailto)
# Out:
# 'amirthaammu2002@gmail.com, sudharsan0693@gmail.com, SHRIKARUNMATHESH S, ashish99anonymous@gmail.com, 19ERECS055.rajdeep@rietjaipur.ac.in, Ashish99anonymous@gmail.com, hariprakaash.cb20@bitsathy.ac.in, Sanjusharma14021999@gmail.com, Subhankar.ee@vitj.ac.in, aleenasarav@gmail.com, imvickykumar999@gmail.com, viraj.ks2001@gmail.com, kameswari2558@gmail.com, omjeeyadav563@gmail.com'

# %%
type(mailto[0])
# Out:
# str

# %%
'''Hi {Ankita Pathak},

We hope that this email finds you in the best of health. 

 
Please note that the deadline for the idea submission for the Hackathon- “{HackRIETJ}”, is {21 June} 2021 11:59 PM IST. We encourage early submissions so that you do not face any last minute hassles. 

No late submissions will be acknowledged and responsibility of making the submission before the due time lies solely with the participants. 

Participants must keep in mind the following instructions in regards to the idea submission:

You can change your submissions by clicking on ‘Submission’ and then ‘Change Submission’, anytime before the submission deadline.
Please make all your submissions well before the submission deadline to avoid any last-minute problems. 
Kindly Submit your PPT in the given form :
    {https://docs.google.com/forms/d/e/1FAIpQLSfZGtewUdn8APM3j7J4D3HLGjtV0f2cMjaBIuP9AegSTNUKww/viewform}

Kindly use the PPT Template given below for reference.

Join our WhatsApp Group for updates and queries: {https://chat.whatsapp.com/Jy2ZdTbfmQoEFtQjNubMpO}

We wish you good luck! Keep innovating!

Competition: HACKRIETJ

Organization: Rajasthan Institute of Engineering and Technology, Jaipur.'''

# %%
import pandas as pd
df = pd.read_csv ('Event Registration (Responses) - Form Responses 1.csv')
df = df.drop(df.index[7])

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

fromaddr = "imvickykumar999@gmail.com"
toaddr = list(set(df['EMAIL ID ( Team Leader )']))

# toaddr = ['imvickykumar999@gmail.com',
#           'hellovickykumar123@gmail.com',
#           'SHRIKARUNMATHESH S',
#          ]  

print(toaddr) 

msg = MIMEMultipart()
msg['From'] = fromaddr
msg['To'] = ','.join(toaddr) 

msg['Subject'] = "Hackathon PPT Template"
body = f'''
Hi,
We hope that this email finds you in the best of health. 

Please note that the deadline for the idea submission for the Hackathon- “HackRIETJ”, is 21 June 2021 11:59 PM IST. 

We encourage early submissions so that you do not face any last minute hassles. 

No late submissions will be acknowledged and responsibility of making the submission before the due time lies solely with the participants. 

Participants must keep in mind the following instructions in regards to the idea submission:

You can change your submissions by clicking on ‘Submission’ and then ‘Edit Submission’, anytime before the submission deadline.

Please make all your submissions well before the submission deadline to avoid any last-minute problems. 

Kindly Submit your PPT in the given form :
https://docs.google.com/forms/d/e/1FAIpQLSfZGtewUdn8APM3j7J4D3HLGjtV0f2cMjaBIuP9AegSTNUKww/viewform

>>> Kindly use the PPT Template from this link : https://drive.google.com/file/d/10f-9wGzc3rIK7vI02owY9WKVzDjaRovi/view?usp=sharing

Join our WhatsApp Group for updates and queries: https://chat.whatsapp.com/Jy2ZdTbfmQoEFtQjNubMpO

We wish you good luck! Keep innovating!

Competition: HACKRIETJ

Organization: Rajasthan Institute of Engineering and Technology, Jaipur.
'''

msg.attach(MIMEText(body, 'plain'))

# filename = 'Hackhathon 2021 template.pptx'
# attachment = open(filename, "rb")

# p = MIMEBase('application', 'octet-stream')
# p.set_payload((attachment).read())
# encoders.encode_base64(p)
# p.add_header('Content-Disposition', "attachment; filename= %s" % filename)
# msg.attach(p)

s = smtplib.SMTP('smtp.gmail.com', 587)
s.starttls()
s.login(fromaddr, "Hellovix999@")

text = msg.as_string()
s.sendmail(fromaddr, toaddr, text)
s.quit()
# Out:
# ['omjeeyadav563@gmail.com', 'SHRIKARUNMATHESH S', 'ashish99anonymous@gmail.com', 'viraj.ks2001@gmail.com', 'kameswari2558@gmail.com', 'Sanjusharma14021999@gmail.com', 'Subhankar.ee@vitj.ac.in', 'imvickykumar999@gmail.com', 'Ashish99anonymous@gmail.com', 'aleenasarav@gmail.com', '19ERECS055.rajdeep@rietjaipur.ac.in', 'amirthaammu2002@gmail.com', 'sudharsan0693@gmail.com', 'hariprakaash.cb20@bitsathy.ac.in']
# (221, b'2.0.0 closing connection g141sm1572727pfb.210 - gsmtp')
