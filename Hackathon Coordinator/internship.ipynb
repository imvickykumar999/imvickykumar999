# %%
d = {'_id': 'b5f134d5-6a56-4af5-9652-a6dc20ecd8b7', 'position': 18, 'title': 'Download Jeremy White - The Gospel Uncut : without pay ebook ...', 'link': 'https://s.romppolotonel.pro/885.html', 'displayed_link': 's.romppolotonel.pro › ...', 'snippet': '... Andrew Farley is the writer of the book “The Naked Gospel” and Jeremy White has written the book “The Gospel Uncut: Learning to Rest in the Grace of God”.', 'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:I_Db_ywJ9zMJ:https://s.romppolotonel.pro/885.html+&cd=28&hl=en&ct=clnk&gl=us', 'case_id': 'ORCA-3593bb9eba37', 'editMode': False, 'deleted': False, 'enabled': True, 'continous_monitoring': False, 'status': None, 'is_profile': False, 'weight': 300, 'search_source': [{'source': 'google', 'search_query': '"Jeremy White has written"', 'job_id': 'fff736c3-2bd1-40e0-8bc8-fbb49a548e21', 'position': 18, 'dt': datetime.datetime(2020, 12, 2, 2, 0, 0, 155000)}]}

# %%
import datetime
import pandas as pd

df = pd.DataFrame.from_dict(d, orient='index')
df
# Out:
#                                                                       0
# _id                                b5f134d5-6a56-4af5-9652-a6dc20ecd8b7
# position                                                             18
# title                 Download Jeremy White - The Gospel Uncut : wit...
# link                               https://s.romppolotonel.pro/885.html
# displayed_link                                s.romppolotonel.pro › ...
# snippet               ... Andrew Farley is the writer of the book “T...
# cached_page_link      https://webcache.googleusercontent.com/search?...
# case_id                                               ORCA-3593bb9eba37
# editMode                                                          False
# deleted                                                           False
# enabled                                                            True
# continous_monitoring                                              False
# ...

# %%
import datetime
import pandas as pd

df = pd.DataFrame.from_dict(d)
df
# Out:
#                                     _id  position  \
# 0  b5f134d5-6a56-4af5-9652-a6dc20ecd8b7        18
#
#                                                title  \
# 0  Download Jeremy White - The Gospel Uncut : wit...
#
#                                    link             displayed_link  \
# 0  https://s.romppolotonel.pro/885.html  s.romppolotonel.pro › ...
#
#                                              snippet  \
# 0  ... Andrew Farley is the writer of the book “T...
#
#                                     cached_page_link            case_id  \
# 0  https://webcache.googleusercontent.com/search?...  ORCA-3593bb9eba37
#
#    editMode  deleted  enabled  continous_monitoring status  is_profile  \
# 0     False    False     True                 False   None       False
#
#    weight                                      search_source
# 0     300  {'source': 'google', 'search_query': '"Jeremy ...

# %%
import pymongo

myclient = mongo_client = pymongo.MongoClient(
                                              'staging.saas.neotas.uk',
                                              username='my_user',
                                              password='password123',
                                              authSource='platformdata',
                                             )
mydb = myclient["platformdata"]
mycol = mydb["google_search_data"]
y = mycol.find()
dictionary ={}

for data in y:
    #print(data)
    dictionary.update(data)

# %%
from pprint import pprint as p
p(dictionary)
# Out:
# {'_id': 'e80c1fc6-a119-49cb-a331-7c789b7352bc',
#  'cached_page_link': 'https://cc.bingj.com/cache.aspx?q=%22TARA+O%27CARROLL%22+%223+Bryanston+Sqaure+3+Bryanston+Sqaure%2c+London%2c+United+Kingdom%2c+W1H+DH%22&d=4974594546729017&mkt=en-US&setlang=en-US&w=lWNYwdEY70rWLwNAJGx5iPO-prc8u4NX',
#  'case_id': 'ORCA-c5aa3ce4daf5',
#  'cite': 'https://beebom.com › Apps',
#  'clicked': True,
#  'continous_monitoring': False,
#  'count': 6,
#  'country': 'Spain',
#  'created_at': datetime.datetime(2021, 6, 23, 8, 36, 0, 794000),
#  'date': 'May 26, 2021',
#  'deleted': False,
#  'displayed_link': 'https://beebom.com › Apps',
#  'displayed_results': 'Results 49 - 96 of 10000+',
#  'domain': 'nl.linkedin.com',
#  'domain_category': {'error': {'message': 'Invalid signed hash or no API '
#                                           'key/secret given'}},
#  'domain_repo': {'reputationScore': 95.0},
#  'dt': datetime.datetime(2021, 6, 23, 8, 36, 0, 792000),
#  'editMode': False,
#  'enabled': True,
# ...

# %%
import datetime
import pandas as pd

df = pd.DataFrame.from_dict(dictionary)
df = df.transpose()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-418700d5e6f0> in <module>
#       2 import pandas as pd
#       3
# ----> 4 df = pd.DataFrame.from_dict(dictionary)
#       5 df = df.transpose()
#       6 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1307             raise ValueError("only recognize index or columns for orient")
#    1308
# -> 1309         return cls(data, index=index, columns=columns, dtype=dtype)
#    1310
#    1311     def to_numpy(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
# ...

# %%
# https://stackoverflow.com/a/13581730/11493297
