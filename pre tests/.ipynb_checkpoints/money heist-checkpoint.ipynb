# %%
import requests
from bs4 import BeautifulSoup 
from pprint import pprint

html_url = "https://onionplay.uk/episodes/money-heist-season-1-episode-8/"
html_response = requests.get(html_url) 
soup = BeautifulSoup(html_response.text, 'html.parser') 


# for mp4 in soup.find_all('video'):
#     mp4 = mp4['src']

# print(mp4)

pprint(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/><link data-optimized="2" href="https://onionplay.uk/content/litespeed/css/e6a663539f453bd823a4aa5e7ec66a82.css?ver=db531" rel="stylesheet"/>
# <link href="https://zeroneplus.stream/2021/01/favicon_red.jpg" rel="apple-touch-icon"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="#000000" name="theme-color"/><link href="https://zeroneplus.stream/2021/01/favicon_red.jpg" rel="shortcut icon" type="image/x-icon"/>
# " property="og:image">
# " property="og:image">
# " property="og:image">
# <title>OnionPlay - Watch Money Heist : Season 1 - Episode 8 Full Episode Stream Online</title>
# ...

# %%
link = 'https://onionplay.uk/episodes/money-heist'

# %%
for i in range(1,6):
    for j in range(1,15):
        print(link + f'-season-{i}-episode-{j}/')
    print()
# Out:
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-1/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-2/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-3/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-4/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-5/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-6/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-7/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-8/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-9/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-10/
# https://onionplay.uk/episodes/money-heist-season-2-episode-6/-season-1-episode-11/
# ...
