# %%
from bs4 import BeautifulSoup
import requests
import csv

url = "https://olympics.com/tokyo-2020/olympic-games/en/results/all-sports/medal-standings.htm"
html_content = requests.get(url).text

soup = BeautifulSoup(html_content, "lxml")
soup
# Out:
# <html lang="en-us" xml:lang="en-us" xmlns="http://www.w3.org/1999/xhtml"><head><meta content="dca=esi, max-age=300s, downstream-ttl=60s" http-equiv="edge-control"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta charset="utf-8"/><meta content="history" name="save"/><title>
# Olympic Medal Count | Tokyo 2020 Olympics (Jul 23-Aug 8, 2021)</title><script type="application/ld+json">{"endDate":"2021-08-08","@type":"SportsEvent","name":"Olympic Games Tokyo 2020\r\n","description":"Olympic Games Tokyo 2020\r\n","location":{"address":"Tokyo, Japan","@type":"Place","name":"Tokyo, Japan"},"@id":"../../../en/results/all-sports/medal-standings.htm","@context":"http://schema.org","url":"../../../en/results/all-sports/medal-standings.htm","startDate":"2021-07-23"}</script><!-- Twitter Card data --><meta content="summary" name="twitter:card"/><meta content="@Tokyo2020" name="twitter:site"/><meta content="Olympic Medal Count | Tokyo 2020 Olympics (Jul 23-Aug 8, 2021)" name="twitter:title"/><meta content="The official website for the Olympic and Paralympic Games Tokyo 2020, providing the latest news, event information, Games Vision, and venue plans." name="twitter:description"/><meta content="@Tokyo2020" name="twitter:creator"/><meta content="https://tokyo2020.org/en/assets/img/common/ogp.jpg" name="twitter:image"/><!-- Open Graph data --><meta content="Olympic Medal Count | Tokyo 2020 Olympics (Jul 23-Aug 8, 2021)" property="og:title"/><meta content="website" property="og:type"/><meta content="../../../en/results/all-sports/medal-standings.htm" property="og:url"/><meta content="https://tokyo2020.org/en/assets/img/common/ogp.jpg" property="og:image"/><meta content="The official website for the Olympic and Paralympic Games Tokyo 2020, providing the latest news, event information, Games Vision, and venue plans." property="og:description"/><meta content="0" property="fb:app_id"/><meta content="Official medal count for the Tokyo 2020 Olympics. Follow the best athletes in the world and find out who won the most gold, silver and bronze medals." name="description"/><link href="https://olympics.com/tokyo-2020/olympic-games/en/results/all-sports/medal-standings.htm" hreflang="en" rel="alternate"/><link href="https://olympics.com/tokyo-2020/olympic-games/es/resultados/todos-los-deportes/clasificacion-por-medallas.htm" hreflang="es" rel="alternate"/><link href="https://olympics.com/tokyo-2020/olympic-games/fr/resultats/tous-les-sports/compte-de-medailles.htm" hreflang="fr" rel="alternate"/><link href="https://olympics.com/tokyo-2020/olympic-games/hi/results/all-sports/medal-standings.htm" hreflang="hi" rel="alternate"/><link href="https://olympics.com/tokyo-2020/olympic-games/zh/results/all-sports/medal-standings.htm" hreflang="zh" rel="alternate"/><link href="https://olympics.com/tokyo-2020/olympic-games/ko/results/all-sports/medal-standings.htm" hreflang="ko" rel="alternate"/><link href="https://olympics.com/tokyo-2020/olympic-games/ja/results/all-sports/medal-standings.htm" hreflang="ja" rel="alternate"/><link href="../../../resOG2020-/style/og2020-.min.css" rel="stylesheet" type="text/css"/><link href="../../../resCOMMON/style/jquery.mThumbnailScroller.css" rel="stylesheet" type="text/css"/><link href="../../../resCOMMON/style/tablesorter.theme.default.css" rel="stylesheet" type="text/css"/><link href="../../../resCOMMON/style/fontawesome.min.css" rel="stylesheet" type="text/css"/><link href="../../../resCOMMON/style/datatables.min.css" rel="stylesheet" type="text/css"/><link href="../../../resCOMMON/style/rwd-table.min.css" rel="stylesheet" type="text/css"/><link href="../../../resOG2020-/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="../../../resOG2020-/img/favicon.ico" rel="icon" type="image/x-icon"/><script src="../../../resCOMMON/sinfoScripts/bundle.js" type="text/javascript"></script><script src="../../../resCOMMON/sinfoScripts/main.js" type="text/javascript"></script><script>
#         var doc = document.documentElement;
#         doc.setAttribute('data-useragent', navigator.userAgent);
# </script><script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script>
#     var gptadslots = [];
#     var googletag = googletag || {cmd:[]};
# </script><script> </script><script>
#     window.addEventListener("load", function(event) {
#         $(window).on("cookies-loaded", function(e, params){
#             if (window.deltatre && window.deltatre.cookieConsent.C0004 == 1) {
#                 googletag.pubads().setRequestNonPersonalizedAds(true);
#             }else {
#                 googletag.pubads().setRequestNonPersonalizedAds(false);
#             };
#         });
#     });
# </script><script>
# googletag.cmd.push(function() {var mapping1 = googletag.sizeMapping().addSize([768, 0], [[728, 90]]).addSize([0, 0], [[320, 50]]).build();var mapping2 = googletag.sizeMapping().addSize([992, 0], [[728, 90]]).addSize([0, 0], []).build();var mapping3 = googletag.sizeMapping().addSize([1250, 0], [[300, 250]]).addSize([992, 0], []).addSize([0, 0], [[320, 50]]).build();googletag.defineSlot('/154962900/tocog2020/medals', [[728,90],[320,50]], 'div-gpt-ad-tokyo2020-1').setTargeting('environment', ['production']).setTargeting('games', ['OG2020-']).setTargeting('lang', ['en']).defineSizeMapping(mapping1).addService(googletag.pubads());googletag.defineSlot('/154962900/tocog2020/medals', [[728,90]], 'div-gpt-ad-tokyo2020-2').setTargeting('environment', ['production']).setTargeting('games', ['OG2020-']).setTargeting('lang', ['en']).defineSizeMapping(mapping2).addService(googletag.pubads());googletag.defineSlot('/154962900/tocog2020/medals', [[300,250],[320, 50]], 'div-gpt-ad-tokyo2020-3').setTargeting('environment', ['production']).setTargeting('games', ['OG2020-']).setTargeting('lang', ['en']).defineSizeMapping(mapping3).addService(googletag.pubads());googletag.pubads().enableLazyLoad({fetchMarginPercent:500,renderMarginPercent:200,mobileScaling: 2.00});});/*google tag fix
# WIDER SOLUTION
# */</script><!--
# google tag fix
# --> <script type="text/javascript">
# (function (w, d, s, l, i) {
# w[l] = w[l] || []; w[l].push({
# 'gtm.start': new Date().getTime(), event: 'gtm.js'
# });
# var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# j.async = true; j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-NV7JFZQ');
# </script> <script type="text/javascript">
# var loaded1 = false;
# var loaded2 = false;
# var loaded3 = false;
# var loadedAth = false;
# window.addEventListener('load', function() {
#     var element1 = document.querySelector('#div-gpt-ad-tokyo2020-1');
#     var position1 = element1.getBoundingClientRect();
#     var element2 = document.querySelector('#div-gpt-ad-tokyo2020-2');
#     var position2 = element2.getBoundingClientRect();
#     var element3 = document.querySelector('#div-gpt-ad-tokyo2020-3');
#     var position3 = element3.getBoundingClientRect();
#     if(!loaded1 && (position1.top < window.innerHeight && position1.bottom >= 0)) {
#         loaded1 = true;
#         loadAdsTrigger(googletag, 1);
#     }
#     if(!loaded2 && (position2.top < window.innerHeight && position2.bottom >= 0)) {
#         loaded2 = true;
#         loadAdsTrigger(googletag, 2);
#     }
#     if(!loaded3 && (position3.top < window.innerHeight && position3.bottom >= 0)) {
#         loaded3 = true;
#         loadAdsTrigger(googletag, 3);
#     }
# });
# window.addEventListener('scroll', function() {
# var element1 = document.querySelector('#div-gpt-ad-tokyo2020-1');
# var position1 = element1.getBoundingClientRect();
# var element2 = document.querySelector('#div-gpt-ad-tokyo2020-2');
# var position2 = element2.getBoundingClientRect();
# var element3 = document.querySelector('#div-gpt-ad-tokyo2020-3');
# var position3 = element3.getBoundingClientRect();
# if(!loaded1 && (position1.top < window.innerHeight && position1.bottom >= 0)) {
#     loaded1 = true;
#     loadAdsTrigger(googletag, 1);
# }
# if(!loaded2 && (position2.top < window.innerHeight && position2.bottom >= 0)) {
#     loaded2 = true;
#     loadAdsTrigger(googletag, 2);
# }
# if(!loaded3 && (position3.top < window.innerHeight && position3.bottom >= 0)) {
#     loaded3 = true;
#    loadAdsTrigger(googletag, 3);
# }
# });
# </script> <script>
#     !function(){
#         var analytics=window.analytics=window.analytics||[];
#         if(!analytics.initialize) {
#             if (analytics.invoked) {
#                 window.console && console.error && console.error("Segment snippet included twice.");
#             }
#             else {
#             analytics.invoked = !0;
#             }
#             analytics.methods = ["identify", "track", "ready", "page", "once", "off", "on", "setAnonymousId"];
#             analytics.factory = function (e) {
#                 return function () {
#                     var t = Array.prototype.slice.call(arguments);
#                     t.unshift(e);
#                     analytics.push(t);
#                     return analytics
#                 }
#             };
#             for (var e = 0; e < analytics.methods.length; e++) {
#                 var key = analytics.methods[e];
#                 analytics[key] = analytics.factory(key);
#             }
#             analytics.load = function (key, e) {
#                 var t = document.createElement("script");
#                 t.type = "text/javascript";
#                 t.async = !0;
#                 t.src = "https://cdn.segment.com/analytics.js/v1/" + key + "/analytics.min.js";
#                 var n = document.getElementsByTagName("script")[0];
#                 n.parentNode.insertBefore(t, n);
#                 analytics._loadOptions = e;
#             };
#             analytics._writeKey="oxLMVAQNW0DB1YhGx9RFMLTabw4dKHna";
#             analytics.SNIPPET_VERSION="4.13.2";
#         };
#     }();
# </script><script>
# $(window).on("cookies-banner-shown", function(e, params) {
#     initSegmentCalls(1);
# });
# $(window).on("cookies-loaded", function(e, params) {
#     initSegmentCalls(2);
# });
# function initSegmentCalls(event) {
#            new SegmentCalls("oxLMVAQNW0DB1YhGx9RFMLTabw4dKHna", event,{"user_nation":"","page_type":"medals","page_hostname":"","non_interaction":0,"partner_name":"Atos","implementation_provider":"Atos","language":"en","screen_id":"../../../en/results/all-sports/medal-standings.htm","content_geography":"","event":"","platform":"Web"});
#        };
# </script></head><body> <section class="d-none">VERSION: 5.9.5.503 (06/08/2021)</section> <input class="sHistory" id="divScrollXPos" name="divScrollXPos" type="hidden"/> <input class="sHistory" id="divScrollYPos" name="divScrollYPos" type="hidden"/> <input class="sHistory" id="scrollXPos" name="scrollXPos" type="hidden"/> <input class="sHistory" id="scrollYPos" name="scrollYPos" type="hidden"/> <div class="tk-ad-top-placeholder"></div> <div class="tk-ad-top tk-ad-top--sticky"> <div class="tk-ad__container--top"> <div class="text-center tk-ads-banner__container"> <div class="tk-ads-banner" id="banner-top"> <div class="text-center wrs-ads" id="div-gpt-ad-tokyo2020-1"></div> </div> </div> </div> </div>
# <div data-request="http://www.olympics.com:8010/external/lib/medals/header" style="display: none"></div>
# <script charset="utf-8" src="/tokyo-2020/en/d3components/scripts/head-externally-shared.min.js?v=20210801" type="text/javascript"></script>
# <script charset="utf-8" id="olympicWidget" src="https://olympics.kiswe.com/widget/kiswe_elements_sdk.min.js" type="text/javascript">
# </script>
# <script>
#         window.tk2020IdentityManagement = window.tk2020IdentityManagement || {};
#         window.tk2020IdentityManagement.apikey = "3_7WJn6CjEnxdOrHeLCAVMtjFPreS-UvLv4U1zutZ-XN5B70ESJDbRis9UIxFrk01w";
#         window.tk2020IdentityManagement.cid = "T2020W";
#         window.tk2020IdentityManagement.culture = "en-US";
#         window.tk2020IdentityManagement.triggerAPIUrl = "https://reengagement.olympicchannel.com/gdfr/trigger/Tokyo2020PreGames/en";
#         window.tk2020IdentityManagement.isTriggerAPIEnabled = "True" === "True";
#         window.tk2020IdentityManagement.triggerTimeout = 2000;
#     </script>
# <!-- Deltatre Cookie Check # START # -->
# <script type="text/javascript">
#     function getCookie(cname) {
#         var name = cname + "=";
#         var decodedCookie = decodeURIComponent(document.cookie);
#         var ca = decodedCookie.split(';');
#         for (var i = 0; i < ca.length; i++) {
#             var c = ca[i];
#             while (c.charAt(0) === ' ') {
#                 c = c.substring(1);
#             }
#             if (c.indexOf(name) === 0) {
#                 return c.substring(name.length, c.length);
#             }
#         }
#         return "";
#     }
#
#     function initDiagnostic() {
#         var enabled = false;
#
#         window.deltatre = window.deltatre || {};
#         window.deltatre.diagnostic = window.deltatre.diagnostic || {};
#
#         if (!window.deltatre.diagnostic.initialized) {
#             var debugCookie = getCookie("d3Debug");
#             enabled = debugCookie.length > 0;
#             window.deltatre.diagnostic.enabled = enabled;
#             window.deltatre.diagnostic.initialized = true;
#             window.deltatre.diagnostic.startTime = Date.now();
#
#             window.deltatre.diagnostic.log = function (toLog) {
#                 if (enabled) {
#                     const millis = Date.now() - window.deltatre.diagnostic.startTime;
#                     console.log(millis + " ms. - " + toLog);
#                 }
#             }
#             window.deltatre.diagnostic.log("D3 - Diagnostic enabled by cookie");
#         }
#     }
#
#     function triggerCookieLoadedEvent(fromOptanon) {
#         if (typeof fromOptanon !== "undefined" && fromOptanon) {
#             if (!window.deltatre.cookieLoadedTriggered) {
#                 window.deltatre.cookieLoadedTriggered = true;
#
#                 var event = new CustomEvent('cookies-loaded');
#                 window.dispatchEvent(event);
#             }
#         }
#
#         var cnt = 0;
#         var consentSetInterval = setInterval(function () {
#             cnt += 1;
#             // Bail if we have not gotten a consent response after 10 seconds.
#             if (cnt === 100)
#                 clearInterval(consentSetInterval);
#
#             if (typeof window.__tcfapi !== 'undefined') { // Check if window.__tcfapi has been set
#                 clearInterval(consentSetInterval);
#
#                 var tcfapiUndefinedInterval = setInterval(function () {
#                     if (typeof window.__tcfapi === 'undefined') {
#                         window.deltatre.diagnostic.log("window.__tcfapi is undefined => load adv");
#
#                         clearInterval(tcfapiUndefinedInterval);
#
#                         if (!window.deltatre.cookieLoadedTriggered) {
#                             window.deltatre.cookieLoadedTriggered = true;
#                             var event = new CustomEvent('cookies-loaded');
#                             window.dispatchEvent(event);
#                         }
#                     }
#                 }, 100);
#
#                 window.__tcfapi('addEventListener', 2, function (tcData, listenerSuccess) {
#                     window.deltatre.diagnostic.log("window.__tcfapi listener ended");
#                 });
#             }
#             cnt++;
#         }, 100);
#     }
#
#     (function () {
#
#         initDiagnostic();
#
#         if ('False' === "true") {
#             triggerCookieLoadedEvent();
#         }
#
#         if (window.deltatre.isAmp) {
#             triggerCookieLoadedEvent(true);
#         }
#
#     })();
#
# </script>
# <!--Deltatre Cookie Check # END # -->
# <!-- OneTrust Deltatre Cookie Check # START # -->
# <script type="text/javascript">
#
#     function decodeOptanonConsentCookie(cookieValue) {
#         var cookieValuesDict = {};
#
#         cookieValue.split("&").forEach(function (element) {
#             var elementKeyValue = element.split("=");
#
#             if (elementKeyValue.length === 2) {
#                 cookieValuesDict[elementKeyValue[0]] = elementKeyValue[1];
#             }
#         });
#
#         return cookieValuesDict;
#     }
#
#     function fillD3ConsentVariablesFromOneTrustCookie() {
#         var optanonConsentCookieContent = getCookie("OptanonConsent");
#
#         if (optanonConsentCookieContent.length > 0) {
#             var cookieValuesDict = decodeOptanonConsentCookie(optanonConsentCookieContent);
#             var optanonCategoriesValues = cookieValuesDict["groups"];
#
#             if (optanonCategoriesValues) {
#                 window.deltatre = window.deltatre || {};
#                 window.deltatre.cookieConsent = {};
#                 optanonCategoriesValues.split(",").forEach(function (category) {
#                     var consentKeyValue = category.split(":");
#                     if (consentKeyValue.length === 2) {
#                         window.deltatre.cookieConsent[consentKeyValue[0]] = consentKeyValue[1];
#                     }
#                 });
#             }
#             window.deltatre.diagnostic.log("D3 variables updated with OneTrustCookie");
#             return true;
#         }
#         return false;
#     }
#
# 	function getUrlParams(sParam) {
# 		var sPageURL = window.location.search.substring(1);
# 		var sURLVariables = sPageURL.split('&');
# 		for (var i = 0; i < sURLVariables.length; i++) {
# 			var sParameterName = sURLVariables[i].split('=');
# 			if (sParameterName[0] == sParam) {
# 				return sParameterName[1];
# 			}
# 		}
# 	}
#
#     (function () {
#         if (!fillD3ConsentVariablesFromOneTrustCookie()) {
#             return;
#         }
#
#         var hasOptanonBoxClosedCookie = getCookie("OptanonAlertBoxClosed").length > 0;
#         var isOptOutMode = window.deltatre.cookieConsent && Object.keys(window.deltatre.cookieConsent).length > 1;
#
#         if (hasOptanonBoxClosedCookie || isOptOutMode) {
#             window.deltatre.diagnostic.log("D3 triggered cookie loaded - " + Date.now());
#             triggerCookieLoadedEvent();
#         } else {
#             window.deltatre.diagnostic.log("cannot read consent from OneTrust cookie");
#         }
#     })();
#
#     window.deltatre.cookieIsSpecialTerritory = function () {
#         window.deltatre.diagnostic.log("Checking if user is in a special territory for cookies");
#         var specialTerritoriesList = 'AU,BR,IN,MX,RU,KR,US,ID,JP';
#         var userNation = window.deltatre.UserNation;
#         if (typeof userNation === "undefined") {
#             $("body").on("userNationReady", function () {
#                 userNation = window.deltatre.UserNation;
#             });
#
#             $("body").trigger("userNationReady");
#         }
#
#         // Check if user nation should be overwritten by query parameter for testing purpose
#         var userNationParam = getUrlParams('user_nation');
#         if (userNationParam) {
#             window.deltatre.diagnostic.log("User nation overwritten by query string parameter. Was: " + userNation + " and has been set to " + userNationParam);
#             userNation = userNationParam.toUpperCase();
#         }
#         window.deltatre.diagnostic.log("Current user nation is: " + userNation + ". Special territories is: " + specialTerritoriesList);
#         var isSpecialTerritory = specialTerritoriesList.indexOf(userNation) !== -1;
#         return isSpecialTerritory;
#     }
#
#     window.deltatre.isTrackingConsentGiven = function () {
#         window.deltatre.diagnostic.log("Checking if tracking consent has been given");
#         var trackingConsentCategory = 'C0004';
#         return (window.deltatre.cookieConsent !== undefined &&
#             window.deltatre.cookieConsent[trackingConsentCategory] &&
#             window.deltatre.cookieConsent[trackingConsentCategory] === "1");
#     }
# </script>
# <!-- OneTrust Deltatre Cookie Check # END # -->
# <!-- OneTrust Cookies Consent Notice start -->
# <script charset="UTF-8" data-domain-script="76d715c4-0d4d-4c64-ac5c-9336575c6885" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	function OptanonWrapper() {
# 		window.deltatre.diagnostic.log("Entering Optanon wrapper function");
# 		var htmlElement = document.querySelector("html");
# 		var pcOpenButton = document.getElementById("onetrust-pc-btn-handler");
# 		var pcCloseButton = document.getElementById("close-pc-btn-handler");
# 		var pcSaveButton = document.querySelector(".save-preference-btn-handler");
# 		var pcRejectButton = document.querySelector(".ot-pc-refuse-all-handler");
# 		var pcAllowAllButton = document.getElementById("accept-recommended-btn-handler");
#
# 		if (pcOpenButton) {
# 			pcOpenButton.addEventListener("click", function () {
# 				htmlElement.classList.add("tk-side-menu-overflowY-hide");
# 			});
# 		}
#
# 		if (pcCloseButton) {
# 			pcCloseButton.addEventListener("click", function () {
# 				htmlElement.classList.remove("tk-side-menu-overflowY-hide");
# 			});
# 		}
#
# 		if (pcRejectButton) {
# 			pcRejectButton.addEventListener("click", function () {
# 				htmlElement.classList.remove("tk-side-menu-overflowY-hide");
# 			});
# 		}
#
# 		if (pcSaveButton) {
# 			pcSaveButton.addEventListener("click", function () {
# 				htmlElement.classList.remove("tk-side-menu-overflowY-hide");
# 			});
# 		}
#
# 		if (pcAllowAllButton) {
# 			pcAllowAllButton.addEventListener("click", function () {
# 				htmlElement.classList.remove("tk-side-menu-overflowY-hide");
# 			});
# 		}
#
# 		$(".optanon-show-settings").on("click", function (e) {
# 			htmlElement.classList.add("tk-side-menu-overflowY-hide");
# 			e.preventDefault();
# 		});
#
# 		window.dataLayer.push({ 'event': 'OneTrustGroupsUpdated' });
#
# 		var consentModelName = "opt-in"; // EU, show banner
# 		try {
# 			consentModelName = Optanon.GetDomainData().ConsentModel.Name;
# 		}
# 		catch (e) { }
#
# 		if (Optanon.IsAlertBoxClosedAndValid()) {
# 			window.deltatre.diagnostic.log("Cookies alert box closed and valid");
# 			fillD3ConsentVariablesFromOneTrustCookie();
#
# 			if (!window.deltatre.cookieLoadedTriggered) {
# 				window.deltatre.diagnostic.log("Optanon wrapper triggered cookie loaded");
# 				triggerCookieLoadedEvent(true);
# 			} else {
# 				var event = new CustomEvent('cookies-consent-updated');
# 				window.dispatchEvent(event);
# 			}
# 		} else {
# 			window.deltatre.diagnostic.log("Cookies alert not yet closed and valid");
# 			if (consentModelName === "opt-out") {
# 				window.deltatre.diagnostic.log("Optanon wrapper triggered cookie loaded in opt out mode");
# 				triggerCookieLoadedEvent(true);
#
# 				// if opt out, all consent should be set by default if the cookie is not present
# 				if (consentModelName === "opt-out" && !window.deltatre.cookieConsent) {
# 					window.deltatre.cookieConsent = { C0001: "1", C0002: "1", C0003: "1", C0004: "1", C0005: "1" };
# 				}
# 			} else {
# 				if (!window.deltatre.cookieBannerShownTriggered) {
# 					window.deltatre.diagnostic.log("Opt in mode, consent not yet ready -> triggering cookies banner shown event");
# 					var event = new CustomEvent('cookies-banner-shown');
# 					window.dispatchEvent(event);
# 					window.deltatre.cookieBannerShownTriggered = true;
# 				} else {
# 					window.deltatre.diagnostic.log("Opt in mode, consent not yet ready and cookies banner shown event already triggered");
# 				}
#
# 			}
# 		}
# 	}
# </script>
# <!-- OneTrust Cookies Consent Notice end -->
# <script charset="utf-8" id="userNation" src="/tokyo-2020/en/d3components/scripts/geo/userGeolocation.min.js" type="text/javascript"></script>
# <link href="/tokyo-2020/en/d3components/styles/fontface.min.css?v=20210801" rel="stylesheet" type="text/css"/>
# <link href="/tokyo-2020/en/d3components/styles/icons-v3.min.css?v=20210801" rel="stylesheet" type="text/css"/>
# <link href="/tokyo-2020/en/d3components/styles/main-external.min.css?v=20210801" rel="stylesheet" type="text/css"/>
# <section class="tk-section tokyo2020--olympics">
# <div class="atos-header">
# <style>
#
# .tk-header.headroom {
#     z-index: 1030;
# }
#
# .tk-ad-top--sticky {
#     z-index: 1060;
# }
#
# #mainContainer.wrs-content {
#     margin-top: 10.875rem;
# }
#
# @media (min-width: 992px) {
#     #mainContainer.wrs-content {
#         margin-top: 11.875rem
#     }
# }
#
# .tk-footer .tk-footer-apps {
#     margin-top: 32px;
# }
#
# @media (min-width: 768px) {
#     .tk-footer .tk-footer-apps {
#         margin-top: 60px;
#     }
# }
#
# :lang(ja-ja) .tk-ads-banner__container--sidebar .tk-ads-banner__label {
#     margin: 8px 0;
#     text-align: center;
# }
#
# .tk-fanzonebanner__container-text--atos span {
# height: auto !important;
# min-height: 60px;
# }
#
# .tk-fanzonebanner__container-icon--atos {
# flex-shrink: 0;
# }
#
# </style>
# <!-- B2P Header inclusion of JS and CSS -->
# <script src="https://olympics.com/components/scripts/b2p/navigation-satellite.js"></script>
# <link href="https://olympics.com/components/styles/navsat.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Barlow+Condensed:wght@600&amp;family=Inter&amp;display=swap" rel="stylesheet"/>
# <nav class="tk-skipToLinks">
# <a class="sr-only sr-only-focusable" href="#tk-languageButton-header">
#                         Skip to language selection
#                     </a>
# <a class="sr-only sr-only-focusable" href="#tk-main-content">
#                         Skip to main content
#                     </a>
# </nav>
# <header class="tk-header headroom tk-header--slim" data-adv="true">
# <!-- B2P HEADER -->
# <script>
# 		window.deltatre = window.deltatre || {};
#         window.deltatre.config = window.deltatre.config || {};
# 		window.deltatre.config.geolocationUrl = "https://olympics.com/api/v1/amp/analytics";
# 		window.deltatre.shopConfig = window.deltatre.shopConfig || {};
# 		window.deltatre.shopConfig.b2pGeoShopConfiguration = { 	"countriesConfiguration": { 		"FR": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"CH": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"DE": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"AT": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"BE": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"DK": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"IT": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"LV": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"BG": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"LT": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"HR": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"LU": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"CY": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"MT": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"CZ": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"NL": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"PL": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"EE": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"PT": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"FI": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"RO": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"SK": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"SI": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"GR": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"ES": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"HU": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"SE": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"IE": { 			"baseUrl": "https://shop.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"GB": { 			"baseUrl": "https://shop2.olympics.com/{lang}", 			"languages": ["en", "fr", "de", "es", "it"], 			"enabled": true 		}, 		"US": { 			"baseUrl": "https://shop3.olympics.com/{lang}", 			"languages": ["en"],  ...
# 		window.deltatre.shopConfig.culture = "en";
#     </script>
# <div class="navigation-main">
# <div class="navigation-main__header">
# <div class="navigation-main__header__logo">
# <a href="https://olympics.com/en/" rel="noopener noreferrer">
# <img alt="Olympics" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-logo.svg"/>
# </a>
# </div>
# <div class="navigation-main__header__right">
# <div class="navigation-main__header__right__link-open visible">
# <a href="#" target="_self">Explore Olympics.com</a>
# </div>
# <div class="navigation-main__header__right__menu-open visible">
# <a class="navigation-main__header__right__menu-open-link"> <img alt="menu-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-icon.svg"/> </a>
# </div>
# <div class="navigation-main__header__right__link-close hidden">
# <a href="#" target="_self">Close menu</a>
# </div>
# <div class="navigation-main__header__right__menu-close hidden">
# <a class="navigation-main__header__right__menu-close-link">
# <img alt="close-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-close-icon.svg"/>
# </a>
# </div>
# </div>
# </div>
# <div class="navigation-main__menu hidden">
# <hr class="navigation-main__menu-divider"/>
# <div class="navigation-main__menu__desktop">
# <div class="navigation-main__menu__desktop__content">
# <ul>
# <li data-content="" id="navigation-satellite-int-oly-committee">
# <a class="" href="https://olympics.com/ioc">IOC</a>
# </li>
# <li data-content="" id="navigation-satellite-tokyo-2020">
# <a class="" href="https://olympics.com/tokyo-2020/en/">Tokyo 2020</a>
# </li>
# <li data-content="" id="navigation-satellite-beijing-2022">
# <a class="" href="https://olympics.com/en/olympic-games/beijing-2022">Beijing 2022</a>
# </li>
# <li data-content="" id="navigation-satellite-paris-2024">
# <a class="" href="https://olympics.com/en/olympic-games/paris-2024">Paris 2024</a>
# </li>
# <li data-content="" id="navigation-satellite-milano-2026">
# <a class="" href="https://olympics.com/en/olympic-games/milano-cortina-2026">Milano Cortina 2026</a>
# </li>
# <li data-content="" id="navigation-satellite-losangeles-2028">
# <a class="" href="https://olympics.com/en/olympic-games/los-angeles-2028">LA 2028</a>
# </li>
# <li data-content="" id="menu-og2032">
# <a class="" href="https://olympics.com/en/olympic-games/brisbane-2032">Brisbane 2032</a>
# </li>
# <li data-content="" id="navigation-satellite-museum">
# <a class="" href="https://olympics.com/museum">Museum</a>
# </li>
# <li data-content="jp,ch" id="navigation-satellite-store">
# <a class="" href="https://tokyo2020shop.jp/">Shop</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="navigation-main__menu-main-divider"></div>
# <div class="navigation-main__menu-main">
# <div class="navigation-main__menu-main__menu-item navigation-main__menu-main-left">
# <ul>
# <li data-content="" id="navigation-satellite-olympic-games">
# <a href="https://olympics.com/en/olympic-games" id="navigation-satellite-olympic-games-link"> Olympic Games</a>
# <div class="navigation-satellite-olympic-games-divider main-menu-item-divider hidden-soft">
# <div class="line"></div>
# <div class="arrow">
# <img alt="arrow-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-icon_arrow.svg"/>
# </div>
# </div>
# </li>
# <li data-content="" id="navigation-satellite-olympic-channel">
# <a href="https://olympics.com/en/olympic-channel" id="navigation-satellite-olympic-channel-link"> Olympic Channel</a>
# <div class="navigation-satellite-olympic-channel-divider main-menu-item-divider hidden-soft">
# <div class="line"></div>
# <div class="arrow">
# <img alt="arrow-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-icon_arrow.svg"/>
# </div>
# </div>
# </li>
# <li data-content="" id="navigation-satellite-news">
# <a href="https://olympics.com/en/news/" id="navigation-satellite-news-link"> News</a>
# <div class="navigation-satellite-news-divider main-menu-item-divider hidden-soft">
# <div class="line"></div>
# <div class="arrow">
# <img alt="arrow-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-icon_arrow.svg"/>
# </div>
# </div>
# </li>
# <li data-content="" id="navigation-satellite-athletes">
# <a href="https://olympics.com/en/athletes/" id="navigation-satellite-athletes-link"> Athletes</a>
# <div class="navigation-satellite-athletes-divider main-menu-item-divider hidden-soft">
# <div class="line"></div>
# <div class="arrow">
# <img alt="arrow-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-icon_arrow.svg"/>
# </div>
# </div>
# </li>
# <li data-content="" id="navigation-satellite-sports">
# <a href="https://olympics.com/en/sports/" id="navigation-satellite-sports-link"> Sports</a>
# <div class="navigation-satellite-sports-divider main-menu-item-divider hidden-soft">
# <div class="line"></div>
# <div class="arrow">
# <img alt="arrow-icon" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-icon_arrow.svg"/>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="navigation-main__menu-main__menu-item navigation-main__menu-main-right">
# <div class="navigation-main__menu-main__menu-item__right-container">
# <div class="navigation-satellite-olympic-games-sub hidden">
# <div class="empty-sub-items">
# <img alt="Olympics" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-image.svg"/>
# <p>Watch replays, the latest news about the Olympic Games</p>
# </div>
# </div>
# <div class="navigation-satellite-olympic-channel-sub hidden">
# <ul>
# <li data-content="" id="navigation-satellite-live-events"><a href="https://olympics.com/en/sport-events/"> Live Events</a></li>
# <li data-content="" id="navigation-satellite-original-series"><a href="https://olympics.com/en/original-series/"> Original Series</a></li>
# <li data-content="" id="navigation-satellite-tv-channel"><a href="https://olympics.com/en/live/"> TV Channel</a></li>
# </ul>
# </div>
# <div class="navigation-satellite-news-sub hidden">
# <ul>
# <li data-content="" id="navigation-satellite-podcast"><a href="https://olympics.com/en/podcast/"> Podcast</a></li>
# <li data-content="" id="navigation-satellite-topics"><a href="https://olympics.com/en/topics/"> Topics</a></li>
# </ul>
# </div>
# <div class="navigation-satellite-athletes-sub hidden">
# <div class="empty-sub-items">
# <img alt="Olympics" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-image.svg"/>
# <p>Watch replays, the latest news about the Olympic athletes</p>
# </div>
# </div>
# <div class="navigation-satellite-sports-sub hidden">
# <div class="empty-sub-items">
# <img alt="Olympics" src="https://olympics.com/images/static/navigation-satellite/navigation-menu-main-image.svg"/>
# <p>Watch replays, the latest news about the Olympic sports</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navigation-main__menu__mobile">
# <ul>
# <li data-content="" id="navigation-satellite-int-oly-committee">
# <a class="" href="https://olympics.com/ioc">IOC</a>
# </li>
# <li data-content="" id="navigation-satellite-tokyo-2020">
# <a class="" href="https://olympics.com/tokyo-2020/en/">Tokyo 2020</a>
# </li>
# <li data-content="" id="navigation-satellite-beijing-2022">
# <a class="" href="https://olympics.com/en/olympic-games/beijing-2022">Beijing 2022</a>
# </li>
# <li data-content="" id="navigation-satellite-paris-2024">
# <a class="" href="https://olympics.com/en/olympic-games/paris-2024">Paris 2024</a>
# </li>
# <li data-content="" id="navigation-satellite-milano-2026">
# <a class="" href="https://olympics.com/en/olympic-games/milano-cortina-2026">Milano Cortina 2026</a>
# </li>
# <li data-content="" id="navigation-satellite-losangeles-2028">
# <a class="" href="https://olympics.com/en/olympic-games/los-angeles-2028">LA 2028</a>
# </li>
# <li data-content="" id="menu-og2032">
# <a class="" href="https://olympics.com/en/olympic-games/brisbane-2032">Brisbane 2032</a>
# </li>
# <li data-content="" id="navigation-satellite-museum">
# <a class="" href="https://olympics.com/museum">Museum</a>
# </li>
# <li data-content="jp,ch" id="navigation-satellite-store">
# <a class="" href="https://tokyo2020shop.jp/">Shop</a>
# </li>
# </ul>
# </div>
# <hr class="navigation-main__bottom-divider"/>
# </div>
# <hr class="navigation-main__bottom-divider"/>
# </div>
# <!-- T2020 HEADER -->
# <div class="tk-header__area d-flex flex-column">
# <div class="tk-header__area--primary order-2">
# <div class="container">
# <div class="tk-emblem">
# <a class="tk-emblem__link" href="/tokyo-2020/en/" title="Tokyo 2020 Olympic Games">
# <span class="sr-only">
#                     Tokyo 2020 Olympic Games
#                 </span>
# </a>
# </div>
# <div class="tk-header__menu-area">
# <nav class="tk-main-nav">
# <h2 class="sr-only">Main Navigation</h2>
# <ul class="tk-main-nav__list d-flex flex-row align-items-center">
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/olympic-games/en/results/all-sports/olympic-schedule-and-results-date=2021-08-08.htm">
#                         Schedule &amp; Results
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/olympic-games/en/results/all-sports/medal-standings.htm">
#                         Medals
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/en/sports/">
#                         Sports
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/en/liveblog">
#                         Liveblog
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/en/news/">
#                         News
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/en/news/videos/">
#                         Videos
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/olympic-games/en/results/all-sports/athletes.htm">
#                         Athletes
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/olympic-games/en/results/all-sports/nocs-list.htm">
#                         Teams/NOC
#                     </a>
# </li>
# <li class="tk-main-nav__item">
# <a class="tk-main-nav__link" href="/tokyo-2020/en/fanzone">
#                         FanZone
#                     </a>
# </li>
# </ul>
# <ul class="tk-main-nav__utility-list">
# <li class="tk-main-nav__utility tk-main-nav__utility--login d-none">
# <button class="tk-main-nav__cta" data-gigyaparams='{"screenSet":"GDFR-FullRegistration-Prod","culture":"en-US","loader":true,"cid":"T2020W","startScreen":"gigya-login-screen"}' data-jshook="gigya-signup" title="Log in">
# <span class="tk-icon-login"></span>
# <span class="tk-main-nav__cta-text">
#                         Log in
#                     </span>
# </button>
# </li>
# <li class="tk-main-nav__utility tk-main-nav__utility--login d-none">
# <button class="tk-main-nav__cta" data-gigyaparams='{"screenSet":"GDFR-Profile-Prod","culture":"en-US","loader":true,"cid":"T2020W"}' data-jshook="gigya-profile" title="My profile">
# <span class="tk-icon-login"></span>
# <span class="tk-main-nav__cta-text">
#                         My profile
#                     </span>
# </button>
# </li>
# <li class="tk-main-nav__utility tk-main-nav__utility--search">
# <button class="tk-main-nav__cta tk-main-nav__cta--search" title="Search">
# <span class="tk-icon-search"></span>
# <span class="tk-main-nav__cta-text">
#                         Search
#                     </span>
# </button>
# </li>
# <li class="tk-main-nav__utility tk-main-nav__utility--menu">
# <button class="tk-main-nav__cta tk-main-nav__cta--menu tk-js-fullmenu" title="Full Menu">
# <span class="tk-main-nav__menu-icon">
# <span class="tk-main-nav__menu-icon-bar"></span>
# <span class="tk-main-nav__menu-icon-bar"></span>
# <span class="tk-main-nav__menu-icon-bar"></span>
# </span>
# <span class="tk-main-nav__cta-text">
#                         Full Menu
#                     </span>
# </button>
# </li>
# </ul>
# </nav>
# </div>
# <span class="tk-header__slim-background"></span>
# </div>
# </div>
# <div class="tk-search-box">
# <div class="tk-search-box__container">
# <label class="sr-only" for="tk-search-box__input-top">Search on Tokyo2020</label>
# <input class="tk-search-box__input" id="tk-search-box__input-top" placeholder="Search on Tokyo2020" type="text" value=""/>
# <div class="tk-search-box__magnifier tk-icon-search tk-search-box__magnifier-mobile--result" data-base-url="https://olympics.com/tokyo-2020/en/" data-competition-id="" data-culture="en" data-error-empty="Please enter a search term in the search box above" data-error-no-match="Input string is not in the correct format" data-search-redirect="search" tabindex="0">
# </div>
# <div class="tk-search-box__error"></div>
# </div>
# <span class="tk-search-box__close tk-icon-close" tabindex="0"></span>
# </div>
# <div class="tk-header__area--secondary order-1">
# <div class="container">
# <div class="tk-header__top-menu-area">
# <nav class="tk-secondary-nav">
# <h2 class="sr-only">Secondary Navigation</h2>
# <ul class="tk-secondary-nav__list">
# <script>
#                 window.deltatre = window.deltatre || {};
#                 window.deltatre.geoShopConfiguration = window.deltatre.geoShopConfiguration || {};
#                 window.deltatre.geoShopConfiguration = { "countriesConfiguration": { "FR": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "CH": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "DE": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "AT": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "BE": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "DK": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "IT": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "LV": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "BG": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "LT": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "HR": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "LU": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "CY": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "MT": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "CZ": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "NL": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "PL": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "EE": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "PT": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "FI": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "RO": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "SK": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "SI": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "GR": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "ES": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "HU": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "SE": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "IE": { "baseUrl": "https://shop.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "GB": { "baseUrl": "https://shop2.olympics.com/{lang}", "languages": ["en", "fr", "de", "es", "it"], "enabled": true }, "US": { "baseUrl": "https://shop3.olympics.com/{lang}", "languages": ["en"], "enabled": true }, "MX": { "baseUrl": "https://shop3.olympics.com/{lang}", "languages": ["en"], "enabled": true }, "JP": { "baseUrl": "https://tokyo2020shop.jp/contents/retail_shop?utm_source=GTW&utm_medium=header&utm_content=&utm_campaign=20210719", "enabled": true }, "CN": { "baseUrl": "https://theolympicstore.tmall.com", "enabled": true } } };
#             </script>
# <li class="tk-secondary-nav__item d-none tk-secondary-nav__shop">
# <a class="tk-secondary-nav__link" href="#" rel="noopener" target="_blank">
# <span class="tk-secondary-nav__icon tk-icon-shop"></span>
# <span class="tk-secondary-nav__text">
#                     Shop
#                 </span>
# </a>
# </li>
# <li class="tk-secondary-nav__item d-none">
# <a class="tk-secondary-nav__link" data-gigyaparams='{"screenSet":"GDFR-FullRegistration-Prod","culture":"en-US","loader":true,"cid":"T2020W","startScreen":"gigya-login-screen"}' data-jshook="gigya-signup" href="#">
# <span class="tk-secondary-nav__icon tk-icon-login"></span>
# <span class="tk-secondary-nav__text">
#                     Log in
#                 </span>
# </a>
# </li>
# <li class="tk-secondary-nav__item d-none">
# <a class="tk-secondary-nav__link" data-gigyaparams='{"screenSet":"GDFR-Profile-Prod","culture":"en-US","loader":true,"cid":"T2020W"}' data-jshook="gigya-profile" href="#">
# <span class="tk-secondary-nav__icon tk-icon-login"></span>
# <span class="tk-secondary-nav__text">
#                     My profile
#                 </span>
# </a>
# </li>
# <li class="tk-secondary-nav__item tk-secondary-nav__item--lang">
# <div class="tk-languages dropdown tk-languages--header">
# <h2 class="sr-only">
#             Website Language
#         </h2>
# <div class="tk-languages__dropdown-wrapper">
# ...
#                                 Action &amp; Legacy
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/sustainability/">
#                                 Sustainability
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/anti-doping/">
#                                 Anti-Doping
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/diversity-inclusion/">
#                                 Diversity &amp; Inclusion
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/event/">
#                                 Participation Programmes
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/event-kids-supporters/">
#                                 Kids Supporters
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/olympictruce/">
#                                 Olympic Truce
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/university/">
#                                 Universities &amp; Colleges
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/volunteer/">
#                                 Volunteers
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/transportation/">
#                                 Transportation
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/testevents/">
#                                 Test Events
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/caring/">
#                                 Recovery and Reconstruction Games
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/games/tokyo-2020-playbooks/">
#                                 Playbooks
#                             </a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="tk-footer__col2 d-none d-md-block col col-md-4">
# <nav class="tk-nav-footer">
# <h3 class="tk-nav-footer__title">
#             About Tokyo 2020 Organising Committee
#         </h3>
# <ul class="tk-nav-footer__list tk-nav-footer__list--about-us">
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/structure/">
#                                 Structure
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/games-plan/">
#                                 Games Plan
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/budgets/">
#                                 Budgets
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/procurement/">
#                                 Procurement
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/marketing/">
#                                 Marketing
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/official-contributor/">
#                                 Contributor
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/organising-committee/accessibility/">
#                                 Accessibility
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/copyright">
#                                 Protection of Intellectual Properties
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://recruiting.tokyo2020.org/en/">
#                                 Staff recruitment
#                             </a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="tk-footer__col3 col col-md-3">
# <nav class="tk-nav-footer">
# <h3 class="tk-nav-footer__title tk-nav-footer__title--sns">
#             Follow the Games
#         </h3>
# <ul class="tk-nav-footer__list tk-nav-footer__list--sns">
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://www.facebook.com/tokyo2020/" rel="noopener" target="_blank" title="Facebook">
# <span class="tk-nav-footer__social-icon tk-icon-facebook-round"></span>
# <span class="sr-only">
#                             Facebook
#                         </span>
# </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://twitter.com/Tokyo2020" rel="noopener" target="_blank" title="Twitter">
# <span class="tk-nav-footer__social-icon tk-icon-twitter"></span>
# <span class="sr-only">
#                             Twitter
#                         </span>
# </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://www.instagram.com/tokyo2020/" rel="noopener" target="_blank" title="Instagram">
# <span class="tk-nav-footer__social-icon tk-icon-instagram"></span>
# <span class="sr-only">
#                             Instagram
#                         </span>
# </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://www.youtube.com/tokyo2020" rel="noopener" target="_blank" title="YouTube">
# <span class="tk-nav-footer__social-icon tk-icon-youtube"></span>
# <span class="sr-only">
#                             YouTube
#                         </span>
# </a>
# </li>
# </ul>
# </nav>
# <div class="tk-languages dropdown tk-languages--footer">
# <h3 class="tk-nav-footer__title">
#             Website Language
#         </h3>
# <div class="tk-languages__dropdown-wrapper">
# <button aria-expanded="false" aria-haspopup="true" aria-label="Current language: English - Click to change language" class="btn dropdown-toggle tk-languages__button tk-languages__button--footer" data-toggle="dropdown" id="tk-languageButton-footer" type="button">
# <span class="tk-icon-language tk-languages__icon"></span>
# <span class="tk-languages__button-label">
#                 English
#             </span>
# <span class="tk-icon-arrow-down tk-languages__button-icon"></span>
# </button>
# <div class="dropdown-menu tk-languages__dropdown-menu tk-languages__dropdown-menu--footer">
# <div class="tk-languages__dropdown-menu-container--animation">
# <div class="tk-languages__dropdown-menu-label">
#                     Select your language
#                 </div>
# <ul>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item" href="/tokyo-2020/ja/">
# <span class="tk-languages__dropdown-item-label" lang="ja-JP">
#                                     日本語
#                                 </span>
# </a>
# </li>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item tk-languages__dropdown-item--current" href="#">
# <span class="tk-languages__dropdown-item-label" lang="en-US">
#                                     English
#                                 </span>
# </a>
# </li>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item" href="/tokyo-2020/fr/">
# <span class="tk-languages__dropdown-item-label" lang="fr-FR">
#                                     Français
#                                 </span>
# </a>
# </li>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item" href="/tokyo-2020/zh/">
# <span class="tk-languages__dropdown-item-label" lang="zh-CN">
#                                     中文
#                                 </span>
# </a>
# </li>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item" href="/tokyo-2020/ko/">
# <span class="tk-languages__dropdown-item-label" lang="ko-KR">
#                                     한국어
#                                 </span>
# </a>
# </li>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item" href="/tokyo-2020/es/">
# <span class="tk-languages__dropdown-item-label" lang="es-ES">
#                                     Español
#                                 </span>
# </a>
# </li>
# <li>
# <a class="dropdown-item tk-languages__dropdown-item" href="/tokyo-2020/hi/">
# <span class="tk-languages__dropdown-item-label" lang="hi-IN">
#                                     हिन्दी
#                                 </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col">
# <nav class="tk-nav-footer">
# <h3 class="tk-nav-footer__title sr-only">
#             Utilities
#         </h3>
# <ul class="tk-nav-footer__list tk-nav-footer__list--footer-links">
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://supporttokyo2020.olympics.com/hc/en-us" rel="noopener" target="_blank">
#                                 FAQ
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/impressum">
#                                 About Us
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/contact-us" target="_self">
#                                 Contact Us
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/web-accessibility" target="_self">
#                                 Web Accessibility
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/link" target="_self">
#                                 Links
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://id.tokyo2020.org/" rel="noopener" target="_blank">
#                                 Tokyo 2020 ID
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://olympics.com/en/terms-of-service" target="_self">
#                                 Terms of Service
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://olympics.com/en/privacy-policy" target="_self">
#                                 Privacy Policy
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://olympics.com/en/cookie-policy" target="_self">
#                                 Cookie Policy
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link optanon-show-settings" href="#" target="_self">
#                                 Cookie Settings
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/using-this-site" target="_self">
#                                 Using this site
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="/tokyo-2020/en/utilities/site-map" target="_self">
#                                 Site Map
#                             </a>
# </li>
# <li class="tk-nav-footer__item">
# <a class="tk-nav-footer__link" href="https://media.tokyo2020.org/" rel="noopener" target="_blank">
#                                 Media
#                             </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <div class="tk-footer__copyright-area">
# <div class="container">
# <div class="row">
# <div class="col-12 col-md-6 order-2 order-md-1">
# <div class="tk-footer__copyright">
# <dl>
# <dt class="tk-footer__copyright-text mb-0">© 2020 – The Tokyo Organising Committee of the Olympic and Paralympic Games</dt>
# <dd class="tk-footer__copyright-text">All rights reserved.</dd>
# </dl>
# </div>
# </div>
# <div class="col-12 col-md-6 order-1 order-md-2">
# <div class="tk-footer__copyright">
# <dl>
# <dt class="tk-footer__copyright-title">Photo by</dt>
# <dd class="tk-footer__copyright-text">
# <nav class="tk-nav-footer">
# <ul class="tk-nav-footer__list tk-nav-footer__list--footer-nolinks">
# <li class="tk-nav-footer__item">
# AFLO SPORT                </li>
# <li class="tk-nav-footer__item">
# Getty Images                </li>
# <li class="tk-nav-footer__item">
# PHOTO KISHIMOTO                </li>
# <li class="tk-nav-footer__item">
# Shugo Takemi                </li>
# </ul>
# </nav>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="optanon-category-C0004" type="text/plain">
#         (function () {
#
#             var dom, doc, where, iframe = document.createElement('iframe');
#             iframe.src = "javascript:false";
#             (iframe.frameElement || iframe).style.cssText = "width: 0; height: 0; border: 0";
#             where = document.getElementsByTagName('script')[0];
#             where.parentNode.insertBefore(iframe, where);
#
#             try {
#                 doc = iframe.contentWindow.document;
#             } catch (e) {
#                 dom = document.domain;
#                 iframe.src = "javascript:var d=document.open();d.domain='" + dom + "';void(0);";
#                 doc = iframe.contentWindow.document;
#             }
#             doc.open()._l = function () {
#                 var js = this.createElement("script");
#                 if (dom) this.domain = dom;
#                 js.id = "boomr-if-as";
#                 js.src = '//c.go-mpulse.net/boomerang/' + '7GSSN-PZSN4-TX76Q-MHL8C-RSE27';
#                 BOOMR_lstart = new Date().getTime();
#                 this.body.appendChild(js);
#             };
#             doc.write('<body onload="document._l();">');
#             doc.close();
#         })();
# </script>
# </footer>
# <script charset="utf-8" src="/tokyo-2020/en/d3components/scripts/bundle-atos.min.js" type="text/javascript"></script>
# <script>
# 	function sendMessage(messageName, data) {
#         $(document).trigger(messageName, data);
#         // Trigger on both document and window
# 		var event = new CustomEvent(messageName);
# 		window.dispatchEvent(event);
# 		window.deltatre.diagnostic.log("UTILS - Sent message " + messageName);
#     };
#
#     function getAnonymousIdFromCookie() {
#         var segmentAnomymousIdCookieValue = getCookie("ajs_anonymous_id");
#         if (segmentAnomymousIdCookieValue) {
# 			return segmentAnomymousIdCookieValue.replace("\"", '').substring(0, 36);
#         }
#     }
#
#     function checkSegmentReadiness(maxCheck, checked) {
#         window.deltatre.diagnostic.log(
#             "### SEGMENT - polling to check if initialization is completed ### Attempt " +
#                 checked +
#                 " of " +
#                 maxCheck
#         );
#         window.deltatre.segmentAnonymousId =
#             (window.analytics &&
#                 typeof window.analytics.user === "function" &&
#                 typeof window.analytics.user().anonymousId === "function" &&
#             window.analytics.user().anonymousId()) ||
#             getAnonymousIdFromCookie() ||
#             null;
#         if (window.deltatre.segmentAnonymousId !== null || checked > maxCheck) {
#             window.deltatre.diagnostic.log("### SEGMENT - initialization completed ###");
#             window.deltatre.diagnostic.log("### SEGMENT - AnonymousId: " + window.deltatre.segmentAnonymousId);
#             window.deltatre.segmentInitializationCompleted = true;
#             sendMessage("segment-ready");
#             sendMessage("trigger-api");
#         } else {
#             setTimeout(function () {
# 				checkSegmentReadiness(maxCheck, ++checked);
# 			}, 500);
#         }
#     }
#
#     checkSegmentReadiness(10, 0);
# </script>
# <div class="tk-olympic-widget" data-options='{"disciplineCode": "ALL"}' data-plugin="olympics-widget">
# </div>
# </body></html>

# %%
gdp_table_data = soup.find_all("tr")
gdp_table_data[0]
# Out:
# <tr> <th class="text-center">
# Rank</th> <th class="text-left">
# Team/NOC</th> <th class="text-center"> <img align="top" alt="Gold Medal" class="medal-icon" src="../../../resOG2020-/img/medals/1.png"/> </th> <th class="text-center"> <img align="top" alt="Silver Medal" class="medal-icon" src="../../../resOG2020-/img/medals/2.png"/> </th> <th class="text-center"> <img align="top" alt="Bronze Medal" class="medal-icon" src="../../../resOG2020-/img/medals/3.png"/> </th> <th class="text-center">
# Total</th> <th class="text-center">
# Rank<br/>by<br/>Total</th> <th class="text-center d-none">
# NOC<br/>Code</th> </tr>

# %%
gdp_table_data[1].find_all('td')[0].contents[1]
# Out:
# <strong>1</strong>
