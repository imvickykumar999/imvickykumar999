# %%
a=3

# %%
a

# %%
def parse():
    return {"sessions":[{"center_id":716743,"name":"ZOMATO LIMITED","address":"SECTOR 132 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"3bb3f277-1c04-4159-b611-67915ce79dfd","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":563029,"name":"Chc Bhangel 45 YEARS","address":"SEC 110 NOIDA G.B.NAGAR","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"1421ab3c-4c69-413c-8ea4-275960e067a1","date":"07-06-2021","available_capacity_dose1":28,"available_capacity_dose2":0,"available_capacity":28,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":720916,"name":"WP 18 YEARSNOIDA AUTHORITYSEC6","address":"SECTOR 6 NOIDA AUTHORITY ","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"District Hospital","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"5fef8cec-f318-4d81-a863-7e243c4f81e0","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":724992,"name":"LIFE STYLE INTERNATIONAL","address":"SECTOR 9 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"35f588ef-045c-4370-a988-bb6390993ef7","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":720926,"name":"18 YRS SAPPHIRE INT. SCHOOL","address":"Sapphire International School Sector 70 Noida Uttar Pradesh India","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"56ee9eb6-dbc1-44af-8046-b5e3b5a72544","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVAXIN","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":607155,"name":"KAILASH HOSPITAL HEART INST","address":"H 33 SECTOR 27 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"e13c96b7-92ce-47b8-9cf3-a127990a4cf9","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"850","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-04:00PM"]},{"center_id":724136,"name":"AMRAPALI SAPPHIRE 2","address":"SECTOR 45 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"c9f94a1e-975f-4521-9c41-8a002f5100b3","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-12:00PM","12:00PM-02:00PM","02:00PM-04:00PM","04:00PM-05:00PM"]},{"center_id":731710,"name":"GLOBAL LOGIC SECTOR 144","address":"SECTOR 144 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"ed178949-1e95-41ce-af39-377dc51a1d45","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-12:00PM","12:00PM-02:00PM","02:00PM-04:00PM","04:00PM-05:00PM"]},{"center_id":713194,"name":"KRONOS SOLUTION INDIA PVT LTD","address":"OKAYA TOWER 4 BLOCK B B5 SECTOR 62 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"694b099b-3950-4ba8-85fe-307ede28e953","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":568862,"name":"18 TO 44 YEARS E.S.I.C","address":"Noida Sec 24","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"NOIDA","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"6014e356-a714-4833-baa9-d69162d440e5","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":727891,"name":"IBM INDIA PVT LTD SECTOR 62","address":"SECTOR 62 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"9ff48355-0388-4e47-8184-7488665c0de5","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-12:00PM","12:00PM-02:00PM","02:00PM-04:00PM","04:00PM-06:00PM"]},{"center_id":716743,"name":"ZOMATO LIMITED","address":"SECTOR 132 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"45552cc1-c16e-4e2f-b72e-0d8de95bd05b","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":724945,"name":"WISHTOWN","address":"CLUB 3 SECTOR 128 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:30:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"8ea6285d-52ce-468c-9dd5-1835f2535384","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:30AM-10:30AM","10:30AM-11:30AM","11:30AM-12:30PM","12:30PM-05:00PM"]},{"center_id":607155,"name":"KAILASH HOSPITAL HEART INST","address":"H 33 SECTOR 27 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"e438cebb-03ad-4268-9f73-3346936e1284","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":1,"available_capacity":1,"fee":"850","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-04:00PM"]},{"center_id":731258,"name":"MAHILA SPECIAL GBN 01 (45)","address":"Sec 30 Noida","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"District Hospital","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"2035f599-759d-4049-bb42-01a955c79130","date":"07-06-2021","available_capacity_dose1":24,"available_capacity_dose2":0,"available_capacity":24,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":713418,"name":"KOTHARIINTERNATIONALSCHOOL18","address":"KOTHARI INTERNATIONAL SCHOOL B Block Sector 50 Noida Uttar Pradesh India","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"247f1277-411c-46f1-8861-9292829bffb8","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":702289,"name":"18 YEARS CHC BISRAKH","address":"CHC BISRAKH Near Deshraj Public School Gautam Buddha Nagar Uttar Pradesh 201301","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"eb84607d-b2ed-4b8a-a530-5f1fafec31ce","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":718597,"name":"BHARTI AIRTEL LIMITED","address":"A 14 A BLOCK INDUSTRIAL AREA SECTOR 62 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"19:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"1a744310-503b-4db4-a9a1-21d96583bcde","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-07:00PM"]},{"center_id":724945,"name":"WISHTOWN","address":"CLUB 3 SECTOR 128 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:30:00","to":"17:30:00","lat":28,"long":77,"fee_type":"Paid","session_id":"9bf355e3-b06b-4ab7-b4c8-4b0b942655fb","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:30AM-11:30AM","11:30AM-01:30PM","01:30PM-03:30PM","03:30PM-05:30PM"]},{"center_id":706941,"name":"18 YEAR GAUR CITYY MALL","address":"GREATER NOIDA W RD GAUR CITY 1 SECTOR 4 OPPOSITE CHAR MURTI CROSSING","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"d0afb43e-0818-44ae-89c4-1e046d41c995","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":700238,"name":"HCL TECH","address":"SECTOR 24 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"679f994c-7f23-42cd-9191-c3166cc6ae8c","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":569387,"name":"PHC BISRAKH 45 YEAR","address":"CHC BISRAKH","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"54659159-fe77-4c73-b073-ded15a811d83","date":"07-06-2021","available_capacity_dose1":206,"available_capacity_dose2":0,"available_capacity":206,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":608408,"name":"APOLLO HOSPITALS PVT","address":"E 2 SECTOR 26 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"14:00:00","lat":19,"long":72,"fee_type":"Paid","session_id":"95f1b41e-df9b-4229-816b-b19f0d95e3c9","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":16,"available_capacity":16,"fee":"850","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-02:00PM"]},{"center_id":723451,"name":"CLOUDNINE HOSPITAL PVT LTD C 9","address":"SECTOR 51 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:30:00","to":"19:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"d377f4c1-d45d-400d-9963-19b0442bd2cc","date":"07-06-2021","available_capacity_dose1":90,"available_capacity_dose2":79,"available_capacity":169,"fee":"900","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:30AM-11:30AM","11:30AM-01:30PM","01:30PM-03:30PM","03:30PM-07:00PM"]},{"center_id":729579,"name":"OIL INDIA SECTOR 16 A NOIDA","address":"SECTOR 16 A NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"3d7be34f-12ee-4b5c-8bbc-fabfc1b0e363","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":703001,"name":"DLF MALL SECTOR 18","address":"DLF MALL SECTOR 18 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"12f2d50d-fff2-4145-a141-3eb9b9db8230","date":"07-06-2021","available_capacity_dose1":18,"available_capacity_dose2":0,"available_capacity":18,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":729579,"name":"OIL INDIA SECTOR 16 A NOIDA","address":"SECTOR 16 A NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"2b8ea01a-214a-4bc0-81cc-f6a5de4a4899","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":700238,"name":"HCL TECH","address":"SECTOR 24 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"0b1fdc9b-79a5-4adc-8295-57d5adf46497","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":702330,"name":"18 YEARS FATHER AGNEL SCHOOL","address":"KHORA COLONY SECTOR 62 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"e23070d7-fed3-4142-be40-71c5daa4b793","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVAXIN","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":682515,"name":"MAX MULTISPECIALITY CENTRE","address":"A 364 SECTOR 19 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"85b2a5ed-198d-4edb-ae58-7747017a0280","date":"07-06-2021","available_capacity_dose1":3,"available_capacity_dose2":45,"available_capacity":48,"fee":"900","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"center_id":724136,"name":"AMRAPALI SAPPHIRE 2","address":"SECTOR 45 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"4b31ad1c-298c-4b9b-acef-a15386049f3c","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-12:00PM","12:00PM-02:00PM","02:00PM-04:00PM","04:00PM-05:00PM"]},{"center_id":568976,"name":"45 DISTRICT COM HOSPITAL","address":"Sec -30 Noida","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"District Hospital","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"0452e5dc-b95c-453d-96ec-cc3840e0a8fd","date":"07-06-2021","available_capacity_dose1":138,"available_capacity_dose2":0,"available_capacity":138,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":562511,"name":"S S P G I 45 YEAR","address":"SECTOR-30 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"5b1df833-8e5f-42f2-91ee-304389f480a5","date":"07-06-2021","available_capacity_dose1":132,"available_capacity_dose2":0,"available_capacity":132,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":713424,"name":"THE MILLENNIUM SCHOOL","address":"The Millennium School Aghapur Sector 41 Noida Uttar Pradesh India","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"cc8ea6ce-c1ad-4dfc-af77-0848a3f8b32d","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":562309,"name":"18 TO 44 YEARS CHC BHANGEL","address":"SEC 110 NOIDA G.B.NAGAR","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"ee9c30db-ebfe-4728-bedb-2e5ddd707093","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":731254,"name":"MAHILA SPECIAL GBN 01 (18-44)","address":"Sec 30 Noida","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"District Hospital","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"0a2d2b95-f45f-4fba-951e-1e9fbd73a9b4","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":723451,"name":"CLOUDNINE HOSPITAL PVT LTD C 9","address":"SECTOR 51 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:30:00","to":"19:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"34872843-deb6-4b54-b690-e00e8f1e33ca","date":"07-06-2021","available_capacity_dose1":114,"available_capacity_dose2":0,"available_capacity":114,"fee":"900","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:30AM-11:30AM","11:30AM-01:30PM","01:30PM-03:30PM","03:30PM-07:00PM"]},{"center_id":713217,"name":"DIR. GEN. OF HYDROCARBONS","address":"SECTOR 73 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"3a7c9276-e1be-4fc6-941b-f78c94f6a2a7","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":713194,"name":"KRONOS SOLUTION INDIA PVT LTD","address":"OKAYA TOWER 4 BLOCK B B5 SECTOR 62 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"8019c234-c74c-47e6-b54c-c8fb22913d3f","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":609976,"name":"PHC BAROLA 45 YEARS","address":"PHC BAROLA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"4a8c391a-9b57-4704-90a5-1edf1f197c08","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":731992,"name":"45 Govt Girls InterCollege","address":"Hoshiyarpur BLOCK E SECTOR 51 NOIDA UTTAR PRADESH","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"13fec705-bd3b-4ecd-9ccf-738c90dee3b4","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVAXIN","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":731710,"name":"GLOBAL LOGIC SECTOR 144","address":"SECTOR 144 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"432574f6-d5e5-4661-a732-be29577f86a5","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-12:00PM","12:00PM-02:00PM","02:00PM-04:00PM","04:00PM-05:00PM"]},{"center_id":718597,"name":"BHARTI AIRTEL LIMITED","address":"A 14 A BLOCK INDUSTRIAL AREA SECTOR 62 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"19:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"6e493ed0-683a-4633-b468-39db843b49ce","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-07:00PM"]},{"center_id":722564,"name":"ABHIBHAVAK SPECIAL 02 (18-44)A","address":"Primary School Near C.H.C BISRAKH G.B. NAGAR (Exclusively For Parents Of Children Below 12 Years Of Age)","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"201cf027-403a-4fce-8991-7d141dc46d8a","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":568853,"name":"Esic Noida 45 YEARS","address":"Noida Sec 24","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"NOIDA","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"f5bc030b-9198-4189-9345-c3a59f02bd8f","date":"07-06-2021","available_capacity_dose1":61,"available_capacity_dose2":0,"available_capacity":61,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":713397,"name":"SPECTRUM METRO MALL","address":"SPECTRUM METRO MALL Block A Sector 75 Noida Uttar Pradesh India","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"4da0e028-51c7-4376-b6f2-486a9e44c45a","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":616302,"name":"UPHC RAIPUR","address":"UPHC RAIPUR","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"9bac1989-3632-4ba6-9178-646bb5df3308","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVAXIN","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":706893,"name":"GIP MALL","address":"GIP MALL SECTOR 38 NEAR PETROL PUMP NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"8d2da63a-3837-4dd2-a210-463ef1aefc09","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVAXIN","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":713217,"name":"DIR. GEN. OF HYDROCARBONS","address":"SECTOR 73 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"dc1d314f-79d7-40ab-8fb8-ad8ddcbe9773","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":682515,"name":"MAX MULTISPECIALITY CENTRE","address":"A 364 SECTOR 19 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"17:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"823b4996-d51a-43d5-9ebb-fe75f10c7236","date":"07-06-2021","available_capacity_dose1":6,"available_capacity_dose2":3,"available_capacity":9,"fee":"900","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"center_id":602641,"name":"DISTRICT COMBINED HOSPITAL","address":"Sec 30 Noida","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"District Hospital","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":0,"long":0,"fee_type":"Free","session_id":"35321bd5-95d5-437c-84c7-fc34cff9e12e","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":696771,"name":"18 TO 44 YEARS S.S.P.G.I","address":"SECTOR 30 GB NAGAR","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"2c040922-4103-4bab-afc5-64293c6521b6","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":610045,"name":"CHC BADALPUR 45 YEARS","address":"CHC BADALPUR","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"2ed94392-a75a-44df-af97-4b72d2d15dc6","date":"07-06-2021","available_capacity_dose1":75,"available_capacity_dose2":0,"available_capacity":75,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]},{"center_id":724992,"name":"LIFE STYLE INTERNATIONAL","address":"SECTOR 9 NOIDA","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Bisrakh","pincode":201301,"from":"09:00:00","to":"18:00:00","lat":28,"long":77,"fee_type":"Paid","session_id":"8fc6e02c-015f-42d1-aa15-207938414341","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-06:00PM"]},{"center_id":715638,"name":"18 YRS DEEWANI COURT","address":"DEEWANI COURT SURAJPUR","state_name":"Uttar Pradesh","district_name":"Gautam Buddha Nagar","block_name":"Dankaur","pincode":201301,"from":"10:00:00","to":"16:00:00","lat":28,"long":77,"fee_type":"Free","session_id":"119947a8-f0f5-4ada-b99c-6081f864dc36","date":"07-06-2021","available_capacity_dose1":0,"available_capacity_dose2":0,"available_capacity":0,"fee":"0","min_age_limit":18,"vaccine":"COVISHIELD","slots":["10:00AM-11:00AM","11:00AM-12:00PM","12:00PM-01:00PM","01:00PM-04:00PM"]}]}

# %%
d = parse()

# %%
type(d)

# %%
k = d.keys()
k

# %%
dk = d['sessions']
dk[0], len(dk)

# %%
import urllib.request
import json

pin = '302020'
date = '07-06-2021'

try:
    with urllib.request.urlopen(f'https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin?pincode={pin}&date={date}') as f:
        data = json.loads(f.read().decode('utf-8'))['sessions']
except urllib.error.URLError as e:
    print(e.reason) 

data

# %%
from pprint import pprint as p

# a = j['fee_type'] == 'Free'
# b = j['min_age_limit'] == 18
# c = j['vaccine'] == 'COVISHIELD'

vaccine = ['COVISHIELD', 'COVAXIN', ]
min_age_limit = 18
l=[]

for i, j in enumerate(data):
    if j['available_capacity_dose2']:
        if j['vaccine'] == vaccine[0]:
            if j['min_age_limit'] == min_age_limit:
                l.append(j)
l

# %%
# type(api_d)

# %%
# import pandas as pd
# df = pd.DataFrame.from_dict(data[1]).drop(['slots'], axis = 1).head(1) 
# df

# %%
# from pprint import pprint as p
import urllib.request
import json

pin = '201301'
date = '07-06-2021'
vaccine = ['COVISHIELD', 'COVAXIN', ][0]
min_age_limit = 18

try:
    with urllib.request.urlopen(f'https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin?pincode={pin}&date={date}') as f:
        data = json.loads(f.read().decode('utf-8'))['sessions']
except urllib.error.URLError as e:
    print(e.reason) 

l=[] 
for i, j in enumerate(data):
#     if j['available_capacity_dose2']:
    if j['available_capacity_dose1']:
        if j['vaccine'] == vaccine:
            if j['min_age_limit'] == min_age_limit:
                l.append(j)
l
# Out:
# [{'center_id': 728593,
#   'name': 'MAX CENTER AL PHATHUM',
#   'address': 'PLOT NO 1 SECTOR 90 NOIDA',
#   'state_name': 'Uttar Pradesh',
#   'district_name': 'Gautam Buddha Nagar',
#   'block_name': 'Bisrakh',
#   'pincode': 201301,
#   'from': '09:30:00',
#   'to': '16:30:00',
#   'lat': 28,
#   'long': 77,
#   'fee_type': 'Paid',
#   'session_id': '0932bcb2-e727-4859-a834-5af1cfd94f72',
#   'date': '07-06-2021',
#   'available_capacity_dose1': 332,
#   'available_capacity_dose2': 20,
#   'available_capacity': 352,
#   'fee': '1100',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['09:30AM-11:30AM',
#    '11:30AM-01:30PM',
#    '01:30PM-03:30PM',
#    '03:30PM-04:30PM']},
#  {'center_id': 721044,
#   'name': 'SCI HEALTHCARE PVT LTD',
#   'address': 'ZYGON SQUARE 3 FLOOR BLOCK H1A SECTOR 63 NOIDA',
#   'state_name': 'Uttar Pradesh',
#   'district_name': 'Gautam Buddha Nagar',
#   'block_name': 'Bisrakh',
#   'pincode': 201301,
#   'from': '13:00:00',
# ...

# %%
df = pd.DataFrame.from_dict(l[1]).drop(['slots'], axis = 1).head(1) 
df

# %%
# from email.mime.text import MIMEText
# from email.mime.multipart import MIMEMultipart
# from email.mime.base import MIMEBase
# import smtplib

# msg = MIMEMultipart()
# msg['From'] = 'imvickykumar999@gmail.com'
# msg['To'] = 'hellovickykumar123@gmail.com'
# msg['Subject'] = 'COVID19 Slot Notification'

# # l='...DATA...'
# body = f'''
# Sent using python code by vicks, Slots is...

# {l}
# '''
# msg.attach(MIMEText(body,'plain'))

# text = msg.as_string()
# server = smtplib.SMTP('smtp.gmail.com',587)
# server.starttls()
# server.login('imvickykumar999@gmail.com','Hellovix999@')
# server.sendmail(msg['From'], msg['To'], text)
# server.quit()

# %%
import pandas as pd

df = pd.DataFrame(data=df, index=[0])
df = (df.T)
print (df)

df.to_excel('covid slot.xlsx')

# %%
len(l), l[1]

# %%
df

# %%
# import pandas as pd
# writer = pd.ExcelWriter('multiple.xlsx', engine='xlsxwriter')

# for i, j in enumerate(l):
#     print(j)
#     print()
#     pd.DataFrame(l[i]).to_excel(writer,
#                                 sheet_name = f'Sheet {i}')
    
# writer.save()

# %%
# # Python code to illustrate Sending mail with attachments
# # from your Gmail account

# # libraries to be imported
# import smtplib
# from email.mime.multipart import MIMEMultipart
# from email.mime.text import MIMEText
# from email.mime.base import MIMEBase
# from email import encoders

# fromaddr = "imvickykumar999@gmail.com"
# toaddr = "hellovickykumar123@gmail.com"

# # instance of MIMEMultipart
# msg = MIMEMultipart()

# # storing the senders email address
# msg['From'] = fromaddr

# # storing the receivers email address
# msg['To'] = toaddr

# # storing the subject
# msg['Subject'] = "COVID19 Slot Notification"

# # string to store the body of the mail
# body = f'''
# Sent using python code by vicks, Slots is...

# {l}
# '''
# # attach the body with the msg instance
# msg.attach(MIMEText(body, 'plain'))

# # open the file to be sent
# filename = "multiple.xlsx"
# attachment = open(filename, "rb")

# # instance of MIMEBase and named as p
# p = MIMEBase('application', 'octet-stream')

# # To change the payload into encoded form
# p.set_payload((attachment).read())

# # encode into base64
# encoders.encode_base64(p)

# p.add_header('Content-Disposition', "attachment; filename= %s" % filename)

# # attach the instance 'p' to instance 'msg'
# msg.attach(p)

# # creates SMTP session
# s = smtplib.SMTP('smtp.gmail.com', 587)

# # start TLS for security
# s.starttls()

# # Authentication
# s.login(fromaddr, "Hellovix999@")

# # Converts the Multipart msg into a string
# text = msg.as_string()

# # sending the mail
# s.sendmail(fromaddr, toaddr, text)

# # terminating the session
# s.quit()

# %%
import pandas as pd

df1 = pd.DataFrame(l[0]) 
df2 = pd.DataFrame(l[1]) 

writer = pd.ExcelWriter('multiple.xlsx', engine='xlsxwriter')

df1.to_excel(writer, sheet_name='Sheet a')
df2.to_excel(writer, sheet_name='Sheet b')

writer.save()

# %%
from datetime import datetime

dnow = datetime.now()
print(dnow) 

# Prints in the format year, month, day, hour, minute, second, and microsecond
# Out:
# 2021-06-06 22:50:54.349690

# %%
from datetime import datetime

dnow = datetime.now()
s = str(dnow).split()[0].split('-')

y = int(s[0])
m = int(s[1])
d = int(s[2])

date = f'{d}-{m}-{y}'
date
# Out:
# '6-6-2021'

# %%
import urllib.request
import json
from datetime import datetime

dnow = datetime.now()
s = str(dnow).split()[0].split('-')

# --------------------------------
y = int(s[0])
m = int(s[1])
d = int(s[2])

date = f'{d+1}-{m}-{y}'
pin = '302020'

vaccine = ['COVISHIELD', 'COVAXIN', ][0]
min_age_limit = 18
filename = "covid slot.xlsx"
# ----------------------------------

try:
    with urllib.request.urlopen(f'https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin?pincode={pin}&date={date}') as f:
        data = json.loads(f.read().decode('utf-8'))['sessions']
except urllib.error.URLError as e:
    print(e.reason) 

l=[] 
for i, j in enumerate(data):
#     if j['available_capacity_dose2']:
        if j['available_capacity_dose1']:
            if j['vaccine'] == vaccine:
                if j['min_age_limit'] == min_age_limit:
                    l.append(j)
print(l)

if l:
    import pandas as pd
    writer = pd.ExcelWriter(filename, engine='xlsxwriter')

    for i, j in enumerate(l):
        print(j)
        print()
        pd.DataFrame(l[i]).to_excel(writer,
                                    sheet_name = f'Sheet {i}') 
    writer.save()

    import smtplib
    from email.mime.multipart import MIMEMultipart
    from email.mime.text import MIMEText
    from email.mime.base import MIMEBase
    from email import encoders

    fromaddr = "imvickykumar999@gmail.com"
    toaddr = "hellovickykumar123@gmail.com"

    msg = MIMEMultipart()
    msg['From'] = fromaddr
    msg['To'] = toaddr

    msg['Subject'] = "COVID19 Slot Notification"
    body = f'''
    
    Book your Slot here : https://selfregistration.cowin.gov.in/
    
    This E-Mail is Sent using python code by vicks,
    Slots is... (open attached excel file) 

    {l}
    '''
    msg.attach(MIMEText(body, 'plain'))
    attachment = open(filename, "rb")

    p = MIMEBase('application', 'octet-stream')
    p.set_payload((attachment).read())
    encoders.encode_base64(p)
    p.add_header('Content-Disposition', "attachment; filename= %s" % filename)
    msg.attach(p)

    s = smtplib.SMTP('smtp.gmail.com', 587)
    s.starttls()
    s.login(fromaddr, "Hellovix999@")

    text = msg.as_string()
    s.sendmail(fromaddr, toaddr, text)
    s.quit() 
    
else:
    print('Email not sent')

# %%
toaddr = "hellovickykumar123@gmail.com"
f = toaddr.split('@')[0]
f, type(f)
# Out:
# ('hellovickykumar123', str)

# %%
# site= "https://github.com/imvickykumar999/hackathon-iot-car-parking"
import urllib.request

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

url = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin?pincode=302020&date=07-06-2021" 
headers={'User-Agent':user_agent,} 

request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
f = response.read() # The data u need
data = json.loads(f.decode('utf-8'))['sessions']
data
# Out:
# [{'center_id': 614649,
#   'name': 'HCG Private Hospital',
#   'address': 'MANSAROVER',
#   'state_name': 'Rajasthan',
#   'district_name': 'Jaipur II',
#   'block_name': 'Jaipur II Urban',
#   'pincode': 302020,
#   'from': '10:00:00',
#   'to': '18:00:00',
#   'lat': 26,
#   'long': 75,
#   'fee_type': 'Paid',
#   'session_id': '7f75cc41-87c2-4940-b7d7-c9f79ef9a60f',
#   'date': '07-06-2021',
#   'available_capacity_dose1': 0,
#   'available_capacity_dose2': 0,
#   'available_capacity': 0,
#   'fee': '850',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['10:00AM-12:00PM',
#    '12:00PM-02:00PM',
#    '02:00PM-04:00PM',
#    '04:00PM-06:00PM']},
#  {'center_id': 604456,
#   'name': 'Mansarovar Sec 8 CVC',
#   'address': 'Mansarovar Sec 8',
#   'state_name': 'Rajasthan',
#   'district_name': 'Jaipur II',
#   'block_name': 'Jaipur II Urban',
#   'pincode': 302020,
#   'from': '09:00:00',
#   'to': '15:00:00',
#   'lat': 0,
#   'long': 0,
#   'fee_type': 'Free',
# ...
